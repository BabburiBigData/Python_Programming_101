# %% [markdown]
# ![image.png](attachment:e98812f2-94df-4d76-922d-25ed42bae750.png)

# %% [markdown]
# ![image.png](attachment:3d4abdf0-a0a8-4d9b-876c-06f13b8cdafe.png)

# %%
#creating a set using {}
sample_set={1,True,"sai",(1,2,3),10+4j}
print(sample_set,type(sample_set))
# Out:
# {1, (1, 2, 3), 'sai', (10+4j)} <class 'set'>

# %%
#create a set using set() constructor
book_set=set(("Harry Potter","Angels & Demons","Atlas shrugged"))
print(book_set,type(book_set))
# Out:
# {'Harry Potter', 'Atlas shrugged', 'Angels & Demons'} <class 'set'>

# %%
#create a set from list.
number_list=[10,20,30,40,50]
sample_list=set(number_list)
print(sample_list)
# Out:
# {40, 10, 50, 20, 30}

# %%
# set of mutable types
sample_set = {'Mark', 'Jessa', [35, 78, 92]}
print(sample_set)
# Output TypeError: unhashable type: 'list' [35, 78, 92]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # set of mutable types
# ----> 2 sample_set = {'Mark', 'Jessa', [35, 78, 92]}
#       3 print(sample_set)
#       4 # Output TypeError: unhashable type: 'list' [35, 78, 92]
#
# TypeError: unhashable type: 'list'

# %%
empty_set=set()
print(type(empty_set))
# Out:
# <class 'set'>

# %%
empty_set={}
print(type(empty_set))
# Out:
# <class 'dict'>

# %%
#Accessing items from a list
book_set = {"Harry Potter", "Angels and Demons", "Atlas Shrugged"}
for item in book_set:
    print(item,type(item))
# Out:
# Atlas Shrugged <class 'str'>
# Angels and Demons <class 'str'>
# Harry Potter <class 'str'>

# %%
# checking if an item exist in a set
book_set = {"Harry Potter", "Angels and Demons", "Atlas Shrugged"}
if "Harry Potter" in book_set:
    print("Book exists in the book set")
else:
    print("Book doesn't exist in the book set")
print("A man called over" in book_set)
# Out:
# Book exists in the book set
# False

# %%
book_set = {"Harry Potter", "Angels and Demons", "Atlas Shrugged"}
len(book_set)
# Out:
# 3

# %%
book_set.add("Sai Vardhan Biopc")
print(book_set)
# Out:
# {'Atlas Shrugged', 'Angels and Demons', 'Harry Potter', 'Sai Vardhan Biopc'}

# %%
book_set.update(["Wings of fire","Hello Python!"])
print(book_set)
# Out:
# {'Atlas Shrugged', 'Angels and Demons', 'Hello Python!', 'Wings of fire', 'Harry Potter', 'Sai Vardhan Biopc'}

# %% [markdown]
# ![image.png](attachment:d16934bb-5841-46e1-9c1a-01f4ca400235.png)

# %%
color_set = {'red', 'orange', 'yellow', 'white', 'black'}
color_set.remove("yellow")

# %%
print(color_set)
# Out:
# {'red', 'white', 'orange', 'black'}

# %%
color_set.discard('white')
print(color_set)
# Out:
# {'red', 'orange', 'black'}

# %%
deleted_item=color_set.pop()
print(deleted_item)
# Out:
# red

# %%
color_set.clear()
print(color_set)
# Out:
# set()

# %%
color_set = {'red', 'orange', 'white', 'black'}
color_set.discard("yellow")

# %%
color_set.remove("yellow")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 color_set.remove("yellow")
#
# KeyError: 'yellow'

# %% [markdown]
# ![image.png](attachment:e0a4c6c1-9fac-4175-bab3-00029ae45890.png)

# %% [markdown]
# ![image.png](attachment:2698aeed-7c05-4078-9263-e484d05da83c.png)

# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
vibgyor=color_set | remaining_colors
print(vibgyor)
# Out:
# {'orange', 'red', 'indigo', 'violet', 'blue', 'green', 'yellow'}

# %%
vibgyor_colors=color_set.union(remaining_colors)
print(vibgyor_colors)
# Out:
# {'orange', 'red', 'indigo', 'violet', 'blue', 'green', 'yellow'}

# %% [markdown]
# ![image.png](attachment:ae303755-483a-43c7-aec8-27aa2d93f29f.png)

# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}
# intersection of two set using & operator
new_set=color_set&remaining_colors
print(new_set)
# Out:
# {'indigo'}

# %%
new_sets=color_set.intersection(remaining_colors)
print(new_sets)
# Out:
# {'indigo'}

# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}

# intersection of two sets
common_colors = color_set.intersection(remaining_colors)
print(common_colors)  # output {'indigo'}
# original set after intersection
print(color_set)
# Output {'indigo', 'violet', 'green', 'yellow', 'blue'}
# Out:
# {'indigo'}
# {'indigo', 'violet', 'blue', 'green', 'yellow'}

# %%
#intersection of two sets using intersection_update()
color_set.intersection_update(remaining_colors)
print(color_set)
# Out:
# {'indigo'}

# %% [markdown]
# ![image.png](attachment:7e055c5d-2bbf-41c7-9da2-27720504ea18.png)

# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}

# difference using '-' operator
print(color_set-remaining_colors)
# Out:
# {'violet', 'blue', 'green', 'yellow'}

# %%
print(color_set.difference(remaining_colors))
# Out:
# {'violet', 'blue', 'green', 'yellow'}

# %%
color_set.difference_update(remaining_colors)
print(color_set)
# Out:
# {'violet', 'blue', 'green', 'yellow'}

# %% [markdown]
# ![image.png](attachment:eb28d639-a4ae-457b-8cf0-76c7db0545f3.png)

# %%
color_set = {'violet', 'indigo', 'blue', 'green', 'yellow'}
remaining_colors = {'indigo', 'orange', 'red'}

# symmetric difference between using ^ operator
unique=color_set ^ remaining_colors
print(unique)
# Out:
# {'red', 'orange', 'violet', 'green', 'blue', 'yellow'}

# %%
# using symmetric_difference()
print(color_set.symmetric_difference(remaining_colors))
# Out:
# {'red', 'orange', 'violet', 'green', 'blue', 'yellow'}

# %%
# using symmetric_difference_update()
color_set.symmetric_difference_update(remaining_colors)
# original set after symmetric_difference_update()
print(color_set)
# Out:
# {'orange', 'red', 'violet', 'blue', 'green', 'yellow'}

# %%
color_set = {'violet', 'blue', 'green', 'yellow'}
color_set1=color_set
print(color_set,type(color_set),id(color_set))
print(color_set1,type(color_set1),id(color_set1))
# Out:
# {'violet', 'blue', 'green', 'yellow'} <class 'set'> 1863521055264
# {'violet', 'blue', 'green', 'yellow'} <class 'set'> 1863521055264

# %%
color_set2=color_set.copy()
print(color_set,type(color_set),id(color_set))
print(color_set2,type(color_set2),id(color_set2))
# Out:
# {'violet', 'blue', 'green', 'yellow'} <class 'set'> 1863521055264
# {'violet', 'blue', 'green', 'yellow'} <class 'set'> 1863520381728

# %%
color_set3=set(color_set)
print(color_set,type(color_set),id(color_set))
print(color_set3,type(color_set3),id(color_set3))
# Out:
# {'violet', 'blue', 'green', 'yellow'} <class 'set'> 1863521055264
# {'violet', 'blue', 'green', 'yellow'} <class 'set'> 1863520670592

# %%
color_set1 = {'violet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red'}
color_set2 = {'indigo', 'orange', 'red'}
print(color_set2.issubset(color_set1))
# Out:
# True

# %%
print(color_set1.issubset(color_set2))
# Out:
# False

# %%
color_set1 = {'violet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red'}
color_set2 = {'indigo', 'orange', 'red'}
print(color_set2.issuperset(color_set1))
# Out:
# False

# %%
print(color_set1.issuperset(color_set2))
# Out:
# True

# %%
color_set1 = {'violet', 'blue', 'yellow', 'red'}
color_set2 = {'orange', 'red'}
color_set3 = {'green', 'orange'}
print(color_set2.isdisjoint(color_set1))
# Out:
# False

# %%
print(color_set3.isdisjoint(color_set1))
# Out:
# True

# %%
set1 = {20, 4, 6, 10, 8, 15}
sorted_list=sorted(set1)
print(sorted_list)
sorted_set=set(sorted_list)
# Out:
# [4, 6, 8, 10, 15, 20]

# %%
set1 = {1, 2, 3, 4}
set2 = {0, 2, 4, 6, 8}  # set with one false value '0'
set3 = {True, True}  # set with all true
set4 = {True, False}  # set with one false
set5 = {False, 0}  # set with both false values
# checking all true value set
print(all(set1))
print(any(set1))
# Out:
# True
# True

# %%
# checking one false value set
print(all(set2))
print(any(set2))
# Out:
# False
# True

# %%
# checking with all true boolean
print(all(set3))
print(any(set3))
# Out:
# True
# True

# %%
# checking with one false boolean
print(all(set4))
print(any(set4))
# Out:
# False
# True

# %%
# checking with all false values
print('all() with all False values:', all(set5))  # False
print('any() with all False values:', any(set5))  # False
# Out:
# all() with all False values: False
# any() with all False values: False

# %%
set1 = {2, 4, 6, 10, 8, 15}
set2 = {'ABC', 'abc'}

# Max item from integer Set
print(max(set1))  # 15

# Max item from string Set
print(max(set2))  # abc

# Minimum item from integer Set
print(min(set1))  # 2

# Minimum item from string Set
print(min(set2))  # ABC
# Out:
# 15
# abc
# 2
# ABC

# %%
rainbow = ('violet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red')
# create a frozenset
f_set = frozenset(rainbow)

print(f_set)
# output frozenset({'green', 'yellow', 'indigo', 'red', 'blue', 'violet', 'orange'})
# Out:
# frozenset({'red', 'violet', 'orange', 'green', 'indigo', 'blue', 'yellow'})

# %%
rainbow = ('violet', 'indigo', 'blue')
f_set = frozenset(rainbow)
# Add to frozenset
f_set.add(f_set)
# output AttributeError: 'frozenset' object has no attribute 'add'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 4
#       2 f_set = frozenset(rainbow)
#       3 # Add to frozenset
# ----> 4 f_set.add(f_set)
#       5 # output AttributeError: 'frozenset' object has no attribute 'add'
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
#All the mathematical operations performed in a set is possible with the frozenset. 
#We can use union(), intersection(), difference(), and symmetric_difference() on a frozenset as well.
#But we can’t use the intersection_update(), difference_update(), and symmetric_difference_update() on frozenset as it is immutable.

# %%
colorset1 = frozenset(('violet', 'indigo', 'blue', 'green'))
colorset2 = frozenset(('blue', 'green', 'red'))

# Mathametical operations with a frozen set

# union
print('The colors of the rainbow are:', colorset1.union(colorset2))
# output frozenset({'red', 'green', 'blue', 'violet', 'indigo'})

# intersection
print('The common colors are:', colorset1.intersection(colorset2))
# output frozenset({'green', 'blue'})

# difference
print('The unique colors in first set are:', colorset1.difference(colorset2))
# output frozenset({'violet', 'indigo'})

print('The unique colors in second set are:', colorset2.difference(colorset1))
# output frozenset({'red'})

# symmetric difference
print('The unique colors second set are:', colorset1.symmetric_difference(colorset2))
# output frozenset({'indigo', 'red', 'violet'})
# Out:
# The colors of the rainbow are: frozenset({'red', 'indigo', 'violet', 'blue', 'green'})
# The common colors are: frozenset({'blue', 'green'})
# The unique colors in first set are: frozenset({'violet', 'indigo'})
# The unique colors in second set are: frozenset({'red'})
# The unique colors second set are: frozenset({'indigo', 'red', 'violet'})

# %%
rainbow = ('violet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red')
other_colors = ('white', 'black', 'pink')
nested=set((frozenset(rainbow),frozenset(other_colors)))
for item in nested:
    print(item)
# Out:
# frozenset({'pink', 'white', 'black'})
# frozenset({'red', 'violet', 'orange', 'green', 'indigo', 'blue', 'yellow'})

# %%
#set comprehension
output_set=set(i**2 for i in range(10) if i%2==0 )
print(output_set)
# Out:
# {0, 64, 4, 36, 16}
